# %%
from collections.abc import Sequence
from pathlib import Path
from typing import Union

import numpy as np
import onnxruntime as ort
import pandas as pd
import torch
from hydra import compose, initialize
from sklearn.metrics.pairwise import cosine_similarity
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from tqdm import tqdm
from transformers import CLIPModel, CLIPProcessor, CLIPTextModelWithProjection

from sneakers_ml.models.onnx_utils import predict_clip, save_clip_model

# %%
class CLIPSimilaritySearchCreator:
    def __init__(self, device: str, clip_model_name: str, onnx_path: str) -> None:
        self.device = device
        self.clip_model_name = clip_model_name
        self.onnx_path = onnx_path
        self.processor = CLIPProcessor.from_pretrained(clip_model_name)

        self._create_onnx_model(self.onnx_path)

        self.clip_model = CLIPModel.from_pretrained(clip_model_name).to(self.device)
        self.clip_model.eval()

    def _create_onnx_model(self, save_path: str) -> None:
        model = CLIPTextModelWithProjection.from_pretrained(self.clip_model_name)
        model.eval()

        text = ["a dummy sentence"]
        inputs = self.processor(text=text, return_tensors="pt", padding=True)

        save_clip_model(model, tuple(inputs.values()), save_path)

    def get_image_features_folder(self, folder_path: str) -> tuple[np.ndarray, np.ndarray, dict[str, int]]:
        dataset = ImageFolder(folder_path, transform=lambda x: self.processor(images=x, return_tensors="pt"))
        dataloader = DataLoader(
            dataset, batch_size=128, shuffle=False, drop_last=False, num_workers=6, pin_memory=False
        )

        image_features = []
        with torch.inference_mode():
            for data in tqdm(dataloader, desc=folder_path):
                images = data[0].to(self.device)["pixel_values"].squeeze(1)
                outputs = self.clip_model.get_image_features(pixel_values=images)
                image_features.append(outputs.cpu())

        full_image_features = torch.cat(image_features, dim=0)
        numpy_image_features = full_image_features.numpy()
        image_paths = np.array(dataset.imgs)

        return numpy_image_features, image_paths, dataset.class_to_idx

    @staticmethod
    def save_features(path: str, numpy_features: np.ndarray, classes: np.ndarray, class_to_idx: dict[str, int]) -> None:
        save_path = Path(path)
        save_path.parent.mkdir(parents=True, exist_ok=True)
        with save_path.open("wb") as save_file:
            np.save(save_file, numpy_features, allow_pickle=False)
            np.save(save_file, classes, allow_pickle=False)
            np.save(save_file, np.array(list(class_to_idx.items())), allow_pickle=False)

    @staticmethod
    def load_features(path: str) -> tuple[np.ndarray, np.ndarray, dict[str, int]]:
        with Path(path).open("rb") as file:
            numpy_features = np.load(file, allow_pickle=False)
            classes = np.load(file, allow_pickle=False)
            class_to_idx_numpy = np.load(file, allow_pickle=False)
            class_to_idx = dict(zip(class_to_idx_numpy[:, 0], class_to_idx_numpy[:, 1].astype(int)))
            return numpy_features, classes, class_to_idx

# %%
# with initialize(version_base=None, config_path="config", job_name="text2image-features-create"):
#     cfg = compose(config_name="cfg_text_to_image")
#     creator = CLIPSimilaritySearchCreator(cfg.device, cfg.base_model, cfg.model_path)
#     numpy_features_, classes_, class_to_idx_ = creator.get_image_features_folder(cfg.images_path)
#     creator.save_features(cfg.embeddings_path, numpy_features_, classes_, class_to_idx_)

# %%
class CLIPTextToImageSimilaritySearch:
    def __init__(self, embeddings_path: str, onnx_path: str, metadata_path: str, clip_model_name: str) -> None:
        self.embeddings_path = embeddings_path
        self.onnx_path = onnx_path
        self.metadata_path = metadata_path

        self.numpy_features, self.classes, self.class_to_idx = CLIPSimilaritySearchCreator.load_features(
            self.embeddings_path
        )
        self.idx_to_class = {str(v): k for k, v in self.class_to_idx.items()}

        self.onnx_session = ort.InferenceSession(self.onnx_path)
        self.processor = CLIPProcessor.from_pretrained(clip_model_name)

        self.df = pd.read_csv(self.metadata_path)
        self.df = self.df.drop(
            ["brand_merge", "images_path", "collection_name", "color", "images_flattened", "title_without_color"],
            axis=1,
        )
        self.df["title"] = self.df["title"].apply(eval)
        self.df["brand"] = self.df["brand"].apply(eval)
        self.df["price"] = self.df["price"].apply(eval)
        self.df["pricecurrency"] = self.df["pricecurrency"].apply(eval)
        self.df["website"] = self.df["website"].apply(eval)
        self.df["url"] = self.df["url"].apply(eval)
        self.df = self.df.explode(["title", "brand", "price", "pricecurrency", "url", "website"])

    def get_text_features(self, text_queries: Union[Sequence[str], str]) -> np.ndarray:
        inputs = self.processor(text=text_queries, return_tensors="np", padding=True)
        return predict_clip(self.onnx_session, inputs)

    def get_similar(self, text_query: str, top_k: int):
        text_features = self.get_text_features(text_query)
        similarity_matrix = cosine_similarity(self.numpy_features, text_features.reshape(1, -1)).flatten()
        top_k_indices = np.argsort(similarity_matrix)[-top_k:][::-1]

        similar_objects = self.classes[top_k_indices]
        similar_images = similar_objects[:, 0]
        similar_models = np.vectorize(self.idx_to_class.get)(similar_objects[:, 1])

        similar_metadata_dump = (
            self.df[self.df["title_merge"].isin(set(similar_models.tolist()))]
            .groupby(["title", "website"])
            .agg(
                {
                    "title_merge": "first",
                    "brand": "first",
                    "price": lambda x: f"{min(x)} - {max(x)}",
                    "pricecurrency": "first",
                    "url": "first",
                }
            )
            .reset_index()
            .to_numpy()
        )
        return similar_metadata_dump, similar_images

# %%
with initialize(version_base=None, config_path="config", job_name="text2image-features-predict"):
    cfg = compose(config_name="cfg_text_to_image")
    temp = CLIPTextToImageSimilaritySearch(cfg.embeddings_path, cfg.model_path, cfg.metadata_path, cfg.base_model)
    print(temp.get_similar("blue sneakers", 3))
# Out:
# (array([["CHUCK TAYLOR ALL STAR HIGH TOP 'LITE BLUE'", 'superkicks',
#         'chuck taylor all star high top', 'Converse', '4299.0 - 4299.0',
#         'INR',
#         'https://www.superkicks.in/products/chuck-taylor-all-star-high-top-lite-blue'],
#        ["GEL-LYTE V GODAI 'ARCTIC BLUE/SKY'", 'superkicks',
#         'gel lyte v godai', 'Asics', '11999.0 - 11999.0', 'INR',
#         'https://www.superkicks.in/products/gel-lyte-v-godai-arctic-blue-sky'],
#        ["GEL-LYTE V GODAI 'EGGPLANT/PURPLE'", 'superkicks',
#         'gel lyte v godai', 'Asics', '11999.0 - 11999.0', 'INR',
#         'https://www.superkicks.in/products/gel-lyte-v-godai-eggplant-purple'],
#        ["GEL-LYTE V GODAI 'SOOTHING SEA/SEAFOAM'", 'superkicks',
#         'gel lyte v godai', 'Asics', '11999.0 - 11999.0', 'INR',
#         'https://www.superkicks.in/products/gel-lyte-v-godai-soothing-sea-seafoam'],
#        ["WMN'S STAN SMITH CS 'CLEAR SKY/WHITE/CORE WHITE'", 'superkicks',
#         'wmns stan smith cs', 'Adidas Originals', '9999.0 - 9999.0',
#         'INR',
#         'https://www.superkicks.in/products/wmns-stan-smith-cs-clear-sky-white-core-white']],
#       dtype=object), array(['data/merged-with-footshop/images/by-models/gel lyte v godai/3.jpeg',
#        'data/merged-with-footshop/images/by-models/chuck taylor all star high top/1.jpeg',
#        'data/merged-with-footshop/images/by-models/wmns stan smith cs/5.jpeg'],
#       dtype='<U118'))

# %%
top_k = 3
text_features = temp.get_text_features("dark blue sneakers")
similarity_matrix = cosine_similarity(temp.numpy_features, text_features).flatten()

# %%
similarity_matrix[np.argsort(similarity_matrix)[-top_k:][::-1]]
# Out:
# array([0.3153295 , 0.3138626 , 0.31370813], dtype=float32)

# %%
np.argsort(similarity_matrix)[-top_k:][::-1]
# Out:
# array([ 9263, 22967, 10474])

# %%
# Get the indices of the top_k most similar items
top_k_indices = np.argsort(similarity_matrix)[-top_k:][::-1]

# %%
similar_objects = temp.classes[top_k_indices]
similar_images = similar_objects[:, 0]
similar_models = np.vectorize(temp.idx_to_class.get)(similar_objects[:, 1])

# %%
text_features = temp._get_text_feature("Dark blue sneakers")

# %%
similarity_matrix = cosine_similarity(temp.numpy_features, text_features).flatten()

# %%
similar_indices = np.argwhere((similarity_matrix >= 0.3) & (similarity_matrix <= 1)).flatten()

# %%
similar_objects = temp.classes[similar_indices]

# %%
similar_images = similar_objects[:, 0]

# %%
similar_images
# Out:
# array(['data/merged-with-footshop/images/by-models/2002r/11.jpeg',
#        'data/merged-with-footshop/images/by-models/2002r/31.jpeg',
#        'data/merged-with-footshop/images/by-models/2002r gore tex/1.jpeg',
#        'data/merged-with-footshop/images/by-models/550/165.jpeg',
#        'data/merged-with-footshop/images/by-models/576/5.jpeg',
#        'data/merged-with-footshop/images/by-models/adifom climacool/39.jpeg',
#        'data/merged-with-footshop/images/by-models/air max terrascape 90/21.jpeg',
#        'data/merged-with-footshop/images/by-models/albatross 82/1.jpeg',
#        'data/merged-with-footshop/images/by-models/all star high trainers/1.jpeg',
#        'data/merged-with-footshop/images/by-models/basket butter goods/0.jpeg',
#        'data/merged-with-footshop/images/by-models/blazer low 77 jumbo/19.jpeg',
#        'data/merged-with-footshop/images/by-models/blazer low 77 jumbo/2.jpeg',
#        'data/merged-with-footshop/images/by-models/campus 80s/62.jpeg',
#        'data/merged-with-footshop/images/by-models/chuck 70/106.jpeg',
#        'data/merged-with-footshop/images/by-models/chuck 70/116.jpeg',
#        'data/merged-with-footshop/images/by-models/chuck 70 beyond retro/0.jpeg',
#        'data/merged-with-footshop/images/by-models/chuck 70 beyond retro/10.jpeg',
#        'data/merged-with-footshop/images/by-models/chuck 70 fall tone/14.jpeg',
#        'data/merged-with-footshop/images/by-models/chuck 70 nautical tri blocked/1.jpeg',
#        'data/merged-with-footshop/images/by-models/chuck 70 ox/3.jpeg',
#        'data/merged-with-footshop/images/by-models/chuck taylor all star/18.jpeg',
#        'data/merged-with-footshop/images/by-models/chuck taylor all star/20.jpeg',
#        'data/merged-with-footshop/images/by-models/chuck taylor all star construct sport remaste/1.jpeg',
#        'data/merged-with-footshop/images/by-models/chuck taylor all star construct sport remaste/2.jpeg',
#        'data/merged-with-footshop/images/by-models/classic leather vintage 40th/12.jpeg',
#        'data/merged-with-footshop/images/by-models/cortez/8.jpeg',
#        'data/merged-with-footshop/images/by-models/country xlg/33.jpeg',
#        'data/merged-with-footshop/images/by-models/dunk low/6.jpeg',
#        'data/merged-with-footshop/images/by-models/fjord eco canvas/0.jpeg',
#        'data/merged-with-footshop/images/by-models/fjord eco canvas/1.jpeg',
#        'data/merged-with-footshop/images/by-models/fjord eco canvas/5.jpeg',
#        'data/merged-with-footshop/images/by-models/forum 84 low/9.jpeg',
#        'data/merged-with-footshop/images/by-models/free og sp/0.jpeg',
#        'data/merged-with-footshop/images/by-models/handball spezial/6.jpeg',
#        'data/merged-with-footshop/images/by-models/hicho/8.jpeg',
#        'data/merged-with-footshop/images/by-models/knu skool/53.jpeg',
#        'data/merged-with-footshop/images/by-models/krink old skool lx/2.jpeg',
#        'data/merged-with-footshop/images/by-models/m cloud 5/12.jpeg',
#        'data/merged-with-footshop/images/by-models/m cloudflow 4/6.jpeg',
#        'data/merged-with-footshop/images/by-models/m cloudswift 3/4.jpeg',
#        'data/merged-with-footshop/images/by-models/medalist low/9.jpeg',
#        'data/merged-with-footshop/images/by-models/nmd r1/46.jpeg',
#        'data/merged-with-footshop/images/by-models/og authentic lx/6.jpeg',
#        'data/merged-with-footshop/images/by-models/og authentic lx/64.jpeg',
#        'data/merged-with-footshop/images/by-models/og authentic lx/69.jpeg',
#        'data/merged-with-footshop/images/by-models/og authentic lx/85.jpeg',
#        'data/merged-with-footshop/images/by-models/og style 24 lx nigel cabourn/5.jpeg',
#        'data/merged-with-footshop/images/by-models/oznova/14.jpeg',
#        'data/merged-with-footshop/images/by-models/project rock 5 disrupt/2.jpeg',
#        'data/merged-with-footshop/images/by-models/project rock bsr 3/1.jpeg',
#        'data/merged-with-footshop/images/by-models/rivalry low/20.jpeg',
#        'data/merged-with-footshop/images/by-models/samba og w/2.jpeg',
#        'data/merged-with-footshop/images/by-models/sk8 hi reissue lx/20.jpeg',
#        'data/merged-with-footshop/images/by-models/sk8 hi reissue lx/23.jpeg',
#        'data/merged-with-footshop/images/by-models/sk8 hi reissue lx/24.jpeg',
#        'data/merged-with-footshop/images/by-models/slipstream lo shroom/1.jpeg',
#        'data/merged-with-footshop/images/by-models/slipstream lo shroom/3.jpeg',
#        'data/merged-with-footshop/images/by-models/slipstream lo shroom/4.jpeg',
#        'data/merged-with-footshop/images/by-models/stan smith crepe/2.jpeg',
#        'data/merged-with-footshop/images/by-models/stussy vandal sp/2.jpeg',
#        'data/merged-with-footshop/images/by-models/vault og sk8 hi lx/2.jpeg',
#        'data/merged-with-footshop/images/by-models/w cloudventure waterproof/11.jpeg',
#        'data/merged-with-footshop/images/by-models/wmns air force 1 07 lx/11.jpeg',
#        'data/merged-with-footshop/images/by-models/wmns air force 1 07 lx/7.jpeg'],
#       dtype='<U118')

# %%
temp.idx_to_class
# Out:
# {'0': '01 low',
#  '1': '01 low m',
#  '2': '01 low man',
#  '3': '01 low w',
#  '4': '01 low wom',
#  '5': '01 low wom leat draw',
#  '6': '101',
#  '7': '101 bex 6 eye boot',
#  '8': '101 ys 6 eye boot',
#  '9': '1460',
#  '10': '1460 8 eye boot',
#  '11': '1460 bex 8 eye boot',
#  '12': '1460 bex squared 8 eye boot',
#  '13': '1460 for pride 8 eye boot',
#  '14': '1460 pascal 8 eye boot',
#  '15': '1460 pascal mono 8 eye boot',
#  '16': '1460 patent leather lace up boots',
#  '17': '1460 serena 8 eye boot',
#  '18': '1460 smooth mono',
#  '19': '1460 vonda 8 eye boot',
#  '20': '1461 3 eye shoe',
#  '21': '1461 for pride',
#  '22': '1461 patent lamper',
#  '23': '1461 quad 3 eye shoe',
#  '24': '1461 smooth',
#  '25': '1490 bloom',
#  '26': '1490 quad squa',
#  '27': '1500',
#  '28': '180',
#  '29': '180 corduroy',
#  '30': '180 pop',
#  '31': '180 tones',
#  '32': '180 w',
#  '33': '1906',
#  '34': '1906 protection pack',
#  '35': '2001 2 high',
#  '36': '2002',
#  '37': '2002 protection pack',
#  '38': '2002r',
#  '39': '2002r gore tex',
#  '40': '2976',
#  '41': '2976 bex',
#  '42': '2976 bex squared chelsea boot',
#  '43': '2976 chelsea boot',
#  '44': '2976 quad chelsea boot',
#  '45': '2976 smooth',
#  '46': '2976 ys',
#  '47': '3 pointer 20',
#  '48': '302',
#  '49': '327',
#  '50': '365 crew',
#  '51': '3d grid hurricane',
#  '52': '4dfwd 3 m',
#  '53': '500',
#  '54': '530',
#  '55': '550',
#  '56': '550 ps',
#  '57': '57 40',
#  '58': '574',
#  '59': '576',
#  '60': '580',
#  '61': '6 in prem shearling',
#  '62': '6 in premium fur lined',
#  '63': '6 inch lace up waterproof boot',
#  '64': '6 inch premium boot',
#  '65': '610',
#  '66': '650',
#  '67': '725',
#  '68': '8enjamin suede',
#  '69': '9060',
#  '70': '920',
#  '71': '990',
#  '72': '990 v1',
#  '73': '990 v2',
#  '74': '990 v3',
#  '75': '990 v4',
#  '76': '990 v6',
#  '77': '990v4',
#  '78': '991',
#  '79': '992',
#  '80': '996',
#  '81': '997',
#  '82': '997h',
#  '83': '998',
#  '84': 'a 630 pu',
#  '85': 'ace spin',
#  '86': 'ace suede',
#  '87': 'acg air deschutz',
#  '88': 'acg air mada',
#  '89': 'acg air mowabb trails end',
#  '90': 'acg air zoom gaiadome gore tex',
#  '91': 'acg lowcate',
#  '92': 'acg lowcate se',
#  '93': 'acg moc',
#  '94': 'acg moc 35',
#  '95': 'acg moc 35 se',
#  '96': 'acg moc premium',
#  '97': 'acg mountain fly 2 low',
#  '98': 'acg mountain fly low gore tex se',
#  '99': 'acg watercat',
#  '100': 'acs',
#  '101': 'acs og',
#  '102': 'acs pro',
#  '103': 'adi2000',
#  '104': 'adi2000 w',
#  '105': 'adi2000 x w',
#  '106': 'adifom adilette',
#  '107': 'adifom climacool',
#  '108': 'adifom sltn',
#  '109': 'adifom sltn w',
#  '110': 'adifom stan mule w',
#  '111': 'adifom supernova',
#  '112': 'adifom superstar',
#  '113': 'adifom superstar boot w',
#  '114': 'adifom trxn',
#  '115': 'adifom trxn w',
#  '116': 'adilette',
#  '117': 'adilette 22',
#  '118': 'adilette 22 w',
#  '119': 'adilette adv w',
#  '120': 'adilette ayoon w',
#  '121': 'adilette essential',
#  '122': 'adilette lite',
#  '123': 'adilette lite w',
#  '124': 'adilette spzl',
#  '125': 'adilette w',
#  '126': 'adimatic',
#  '127': 'adimatic bodega',
#  '128': 'adimatic mid ynuk',
#  '129': 'adimatic mid youth of paris',
#  '130': 'adimatic ynuk',
#  '131': 'adimule lea',
#  '132': 'adistar cushion',
#  '133': 'adrian bex',
#  '134': 'adrian mono tassel loafer',
#  '135': 'afew gt ii',
#  '136': 'air alpha force 88',
#  '137': 'air alpha force sp',
#  '138': 'air dunk jumbo',
#  '139': 'air flight 89',
#  '140': 'air flight 89 le',
#  '141': 'air flight lite mid',
#  '142': 'air force 1',
#  '143': 'air force 1 07',
#  '144': 'air force 1 07 fly ease',
#  '145': 'air force 1 07 fresh',
#  '146': 'air force 1 07 lv8',
#  '147': 'air force 1 07 lv8 2',
#  '148': 'air force 1 07 lv8 nn',
#  '149': 'air force 1 07 lx',
#  '150': 'air force 1 07 mid fresh',
#  '151': 'air force 1 07 se',
#  '152': 'air force 1 07 wb',
#  '153': 'air force 1 crater flyknit',
#  '154': 'air force 1 gore tex',
#  '155': 'air force 1 high 07',
#  '156': 'air force 1 high 07 lv8',
#  '157': 'air force 1 lover xx',
#  '158': 'air force 1 low',
#  '159': 'air force 1 low retro',
#  '160': 'air force 1 low retro qs',
#  '161': 'air force 1 luxe',
#  '162': 'air force 1 lv8',
#  '163': 'air force 1 mid 07',
#  '164': 'air force 1 mid 07 lv8',
#  '165': 'air force 1 mid 07 qs',
#  '166': 'air force 1 react',
#  '167': 'air force 1 sp',
#  '168': 'air force mid 07 lx',
#  '169': 'air ghost racer',
#  '170': 'air huarache',
#  '171': 'air huarache craft',
#  '172': 'air huarache crater prm',
#  '173': 'air huarache premium',
#  '174': 'air huarache runner',
#  '175': 'air humara',
#  '176': 'air jordan 1 mid',
#  '177': 'air jordan 1 mid se',
#  '178': 'air jordan 1 retro low og',
#  '179': 'air jordan 1 zoom cmft 2',
#  '180': 'air jordan 11 cmft low',
#  '181': 'air jordan 11 retro low',
#  '182': 'air jordan 11 retro low ie',
#  '183': 'air jordan 13 retro',
#  '184': 'air jordan 2 retro',
#  '185': 'air jordan 2 retro low',
#  '186': 'air jordan 3 fear',
#  '187': 'air jordan 3 retro',
#  '188': 'air jordan 5',
#  '189': 'air jordan 5 retro se craft',
#  '190': 'air jordan 6 retro',
#  '191': 'air jordan 6 retro gs',
#  '192': 'air jordan 7',
#  '193': 'air jordan 7 retro',
#  '194': 'air jordan retro 5 se',
#  '195': 'air kukini se',
#  '196': 'air max 1',
#  '197': 'air max 1 86 premium',
#  '198': 'air max 1 premium',
#  '199': 'air max 1 premium 2',
#  '200': 'air max 1 premium essential',
#  '201': 'air max 1 premium shima shima',
#  '202': 'air max 1 prm',
#  '203': 'air max 1 sc',
#  '204': 'air max 1 slide',
#  '205': 'air max 2 cb 94',
#  '206': 'air max 90',
#  '207': 'air max 90 futura',
#  '208': 'air max 90 gtx',
#  '209': 'air max 90 ltr',
#  '210': 'air max 90 w',
#  '211': 'air max 95',
#  '212': 'air max 95 premium',
#  '213': 'air max 95 qs',
#  '214': 'air max 95 se',
#  '215': 'air max 97',
#  '216': 'air max 97 futura',
#  '217': 'air max 97 og',
#  '218': 'air max 97 se',
#  '219': 'air max bliss',
#  '220': 'air max flyknit racer',
#  '221': 'air max genome',
#  '222': 'air max motif',
#  '223': 'air max penny',
#  '224': 'air max plus se',
#  '225': 'air max pre day',
#  '226': 'air max scorpion fk se',
#  '227': 'air max scorpion flyknit',
#  '228': 'air max terrascape 90',
#  '229': 'air max tw',
#  '230': 'air max up',
#  '231': 'air max verona',
#  '232': 'air max zephyr',
#  '233': 'air max2 cb 94',
#  '234': 'air more uptempo',
#  '235': 'air more uptempo 96',
#  '236': 'air more uptempo low sp mens shoes',
#  '237': 'air pegasus 83 premium',
#  '238': 'air pegasus 89',
#  '239': 'air penny 2',
#  '240': 'air presto',
#  '241': 'air presto halloween',
#  '242': 'air presto mid utility',
#  '243': 'air presto premium',
#  '244': 'air presto premium social fc',
#  '245': 'air trainer 1',
#  '246': 'air vapormax 2023 flyknit',
#  '247': 'air vapormax 2023 flynit',
#  '248': 'air vapormax moc roam',
#  '249': 'air zoom flight 95',
#  '250': 'ajatu court formal',
#  '251': 'ajatu court hig',
#  '252': 'ajatu run',
#  '253': 'akando atr',
#  '254': 'albatross 82',
#  '255': 'alife nizza hi',
#  '256': 'all star all terrain',
#  '257': 'all star hi',
#  '258': 'all star high trainers',
#  '259': 'all star low trainers',
#  '260': 'all star move hi',
#  '261': 'all star slide',
#  '262': 'all star slide archive paint splatter print',
#  '263': 'all star slide slip',
#  '264': 'all stars hi top mens trainers',
#  '265': 'all terrain atlas clog',
#  '266': 'all terrain clog',
#  '267': 'alp fwd black casual',
#  '268': 'alpargata recycled cotton canvas',
#  '269': 'alpargata rover',
#  '270': 'amzn gore tex mte 3',
#  '271': 'amzn pacu',
#  '272': 'amzn trailhead',
#  '273': 'anaheim era 95',
#  '274': 'anaheim sk8 hi',
#  '275': 'answer 5 x eric emanuel',
#  '276': 'answer iv',
#  '277': 'apc gel sonoma 15 50',
#  '278': 'aria 95',
#  '279': 'arizona bf',
#  '280': 'arizona bf sfb',
#  '281': 'arizona bfbc',
#  '282': 'arizona eva',
#  '283': 'arizona exq le',
#  '284': 'arizona nl',
#  '285': 'arizona sfb',
#  '286': 'arizona sfb vl',
#  '287': 'arizona suede leather',
#  '288': 'arizona vl',
#  '289': 'arizona vl shearling',
#  '290': 'arkesden spzl',
#  '291': 'arkyn',
#  '292': 'army sneaker low monogram',
#  '293': 'as 1 pro',
#  '294': 'ashcott cup',
#  '295': 'astir her vegan w',
#  '296': 'astir sandal w',
#  '297': 'astir sn',
#  '298': 'astir sn w',
#  '299': 'astir sndl w',
#  '300': 'astir thebe magugu',
#  '301': 'astir w',
#  '302': 'astra',
#  '303': 'atr pump vertical',
#  '304': 'attack',
#  '305': 'aubetaie mono',
#  '306': 'audrick 10i boot',
#  '307': 'audrick 3 eye shoe 3 eye shoe',
#  '308': 'audrick 8 eye boot 8 eye boot',
#  '309': 'aussie',
#  '310': 'aussie mono',
#  '311': 'authentic 44 dx',
#  '312': 'authentic 44 dx anaheim factory',
#  '313': 'authentic 44 dx pw anaheim factory',
#  '314': 'authentic 44 lug dx',
#  '315': 'authentic lx',
#  '316': 'authentic lx stealth',
#  '317': 'authentic mixed utility',
#  '318': 'authentic one piece vlt lx',
#  '319': 'authentic vibram dx',
#  '320': 'authentic vibram lx',
#  '321': 'authentic vr3 pw lx',
#  '322': 'avryn',
#  '323': 'aztrek 96',
#  '324': 'aztrek 96 reinvente',
#  '325': 'azura',
#  '326': 'b481',
#  '327': 'b509',
#  '328': 'back to berkeley iv high pile',
#  '329': 'bad bunny campus',
#  '330': 'bad bunny response cl',
#  '331': 'barbados eva',
#  '332': 'basket butter goods',
#  '333': 'basket x butter goods',
#  '334': 'basketball jd1',
#  '335': 'bb 4000',
#  '336': 'bb 4000 ii',
#  '337': 'bb 4000 ii basketball',
#  '338': 'bb 4000 ii mid',
#  '339': 'bb 4000 li mid',
#  '340': 'bb court lo',
#  '341': 'bbw550',
#  '342': 'be do win sp',
#  '343': 'beatnik',
#  '344': 'bedwin the heartbreakers og authentic lx',
#  '345': 'bedwin the heartbreakers og old skool lx',
#  '346': 'bell gel sonoma 15 50',
#  '347': 'bend suede leather',
#  '348': 'bermuda',
#  '349': 'billionaire boys club answer v basketball shoes',
#  '350': 'blaire',
#  '351': 'blaire slide',
#  '352': 'blaze of glory',
#  '353': 'blaze of glory energy',
#  '354': 'blaze of glory premium',
#  '355': 'blaze of glory prm',
#  '356': 'blaze of glory stb',
#  '357': 'blazer 77',
#  '358': 'blazer 77 remaste',
#  '359': 'blazer low',
#  '360': 'blazer low 77',
#  '361': 'blazer low 77 jumbo',
#  '362': 'blazer low 77 jumbo wntr',
#  '363': 'blazer low 77 premium',
#  '364': 'blazer low 77 se remix',
#  '365': 'blazer low 77 vintage',
#  '366': 'blazer low jumbo',
#  '367': 'blazer low leather',
#  '368': 'blazer low platform',
#  '369': 'blazer low x',
#  '370': 'blazer low x acronym',
#  '371': 'blazer mid',
#  '372': 'blazer mid 77',
#  '373': 'blazer mid 77 jumbo',
#  '374': 'blazer mid 77 next nature',
#  '375': 'blazer mid 77 premium',
#  '376': 'blazer mid 77 vintage',
#  '377': 'blazer mid 77 vntg nas',
#  '378': 'blazer mid jumbo',
#  '379': 'blazer mid next nature',
#  '380': 'blazer mid prm',
#  '381': 'blazer mid77 vintage',
#  '382': 'blazer phantom',
#  '383': 'blktop rider',
#  '384': 'blktop rider leather',
#  '385': 'blktop rider lithium',
#  '386': 'blktop rider nostalgia club',
#  '387': 'blktop rider pop',
#  '388': 'blktop rider prm',
#  '389': 'blktop rider washed',
#  '390': 'block stepper mesh',
#  '391': 'block stepper sandal lea mesh',
#  '392': 'block stepper suede',
#  '393': 'block stepper vintage',
#  '394': 'blondey continental',
#  '395': 'bloom',
#  '396': 'bold ni',
#  '397': 'bold ni lx dobale',
#  '398': 'boot guard',
#  '399': 'boot skoot lx',
#  '400': 'boston',
#  '401': 'boston 11',
#  '402': 'boston bs vegan',
#  '403': 'boston eva',
#  '404': 'boston leoi',
#  '405': 'boston micro fibre',
#  '406': 'boston natural leather',
#  '407': 'boston sfb leve',
#  '408': 'boston sfb vl',
#  '409': 'boston sl nl',
#  '410': 'boston suede embossed',
#  '411': 'boston suede leather',
#  '412': 'boston syn',
#  '413': 'boston vl',
#  '414': 'boston vl laf',
#  '415': 'boston vl sfb',
#  '416': 'boston vl shearling',
#  '417': 'brooklyn buckle low wedge',
#  '418': 'brutus sandal',
#  '419': 'bryson grained leather lena',
#  '420': 'bryson grained natural leather',
#  '421': 'butter goods suede vtg hs',
#  '422': 'buwick',
#  '423': 'byw select',
#  '424': 'ca pro',
#  '425': 'ca pro classic',
#  '426': 'ca pro lux cord',
#  '427': 'ca pro prm wns',
#  '428': 'ca pro wns',
#  '429': 'cali court',
#  '430': 'cali dream animal w',
#  '431': 'cali dream first sense wns island',
#  '432': 'cali dream thrifted',
#  '433': 'cali star wns',
#  '434': 'calm slide',
#  '435': 'calm slide w',
#  '436': 'campo',
#  '437': 'campo canvas',
#  '438': 'campo canvas w',
#  '439': 'campo chfree',
#  '440': 'campo chromefree',
#  '441': 'campo chromefree leather',
#  '442': 'campo w',
#  '443': 'campus',
#  '444': 'campus 00s',
#  '445': 'campus 00s clabetaic',
#  '446': 'campus 00s youth of paris',
#  '447': 'campus 2',
#  '448': 'campus 80 crop',
#  '449': 'campus 80s',
#  '450': 'campus 80s cheshire cat',
#  '451': 'campus howlin rays',
#  '452': 'caravan mid',
#  '453': 'cardi b cardi slide',
#  '454': 'cardi b club c',
#  '455': 'cardi b club c v2',
#  '456': 'cardi b club v2',
#  '457': 'cardi b f s hi',
#  '458': 'cardi b slide modern',
#  '459': 'cardi b slides',
#  '460': 'cell dome king x dua lipa',
#  '461': 'centennial 85 hi',
#  '462': 'centennial 85 lo',
#  '463': 'centennial 85 lo w',
#  '464': 'centennial 85 low',
#  '465': 'centennial hi',
#  '466': 'centennial lo',
#  '467': 'chuck 70',
#  '468': 'chuck 70 at cx',
#  '469': 'chuck 70 at cx deep tone',
#  '470': 'chuck 70 at cx future comfort',
#  '471': 'chuck 70 at cx high',
#  '472': 'chuck 70 at cx mono',
#  '473': 'chuck 70 at cx platform',
#  '474': 'chuck 70 beyond retro',
#  '475': 'chuck 70 clabetaic low',
#  '476': 'chuck 70 counter climate',
#  '477': 'chuck 70 craft mix',
#  '478': 'chuck 70 crafted ollie patch',
#  '479': 'chuck 70 fall tone',
#  '480': 'chuck 70 gore tex',
#  '481': 'chuck 70 gtx',
#  '482': 'chuck 70 heritage',
#  '483': 'chuck 70 hi',
#  '484': 'chuck 70 hi summer tone',
#  '485': 'chuck 70 hickory stripe',
#  '486': 'chuck 70 high',
#  '487': 'chuck 70 hiking stitched',
#  '488': 'chuck 70 leather',
#  '489': 'chuck 70 marquis',
#  '490': 'chuck 70 marquis hi',
#  '491': 'chuck 70 marquis seasonal',
#  '492': 'chuck 70 marquis sport remaste',
#  '493': 'chuck 70 marquis warm winter essentials',
#  '494': 'chuck 70 millennium glam',
#  '495': 'chuck 70 mule recycled canvas',
#  '496': 'chuck 70 nautical tri blocked',
#  '497': 'chuck 70 ox',
#  '498': 'chuck 70 plus',
#  '499': 'chuck 70 plus hi',
#  '500': 'chuck 70 plus mixed material',
#  '501': 'chuck 70 plus seasonal',
#  '502': 'chuck 70 plus summer utility',
#  '503': 'chuck 70 seasonal',
#  '504': 'chuck 70 south of houston',
#  '505': 'chuck 70 spray paint',
#  '506': 'chuck 70 summer florals',
#  '507': 'chuck 70 summer tone',
#  '508': 'chuck 70 translucent caged',
#  '509': 'chuck 70 tropical leaf',
#  '510': 'chuck 70 vintage canvas',
#  '511': 'chuck taylor 70 low top red sole',
#  '512': 'chuck taylor all star',
#  '513': 'chuck taylor all star 70 hi',
#  '514': 'chuck taylor all star 70 ox',
#  '515': 'chuck taylor all star all terrain',
#  '516': 'chuck taylor all star city trek waterproof boot',
#  '517': 'chuck taylor all star construct',
#  '518': 'chuck taylor all star construct city workwear',
#  '519': 'chuck taylor all star construct hi',
#  '520': 'chuck taylor all star construct sport remaste',
#  '521': 'chuck taylor all star construct summer tone',
#  '522': 'chuck taylor all star cruise',
#  '523': 'chuck taylor all star cx explore',
#  '524': 'chuck taylor all star cx explore sport remaste',
#  '525': 'chuck taylor all star cx flyease ox',
#  '526': 'chuck taylor all star cx marbled',
#  '527': 'chuck taylor all star cx stretch canvas',
#  '528': 'chuck taylor all star hi',
#  '529': 'chuck taylor all star hi cx future comfort',
#  '530': 'chuck taylor all star high top',
#  '531': 'chuck taylor all star lift',
#  '532': 'chuck taylor all star lift clean',
#  '533': 'chuck taylor all star lift clean ox',
#  '534': 'chuck taylor all star lift hi',
#  '535': 'chuck taylor all star lift ox',
#  '536': 'chuck taylor all star lift platform',
#  '537': 'chuck taylor all star lift platform counter climate',
#  '538': 'chuck taylor all star lift platform leather',
#  '539': 'chuck taylor all star lift platform luxe workwear',
#  '540': 'chuck taylor all star lift platform outline sketch',
#  '541': 'chuck taylor all star lift seasonal',
#  '542': 'chuck taylor all star low top dragon scale',
#  '543': 'chuck taylor all star lugged 20',
#  '544': 'chuck taylor all star lugged 20 counter climate',
#  '545': 'chuck taylor all star lugged 20 leather',
#  '546': 'chuck taylor all star lugged 20 platform counter climate extra high',
#  '547': 'chuck taylor all star lugged 20 platform denim fashion',
#  '548': 'chuck taylor all star lugged winter 20',
#  '549': 'chuck taylor all star move cx platform',
#  '550': 'chuck taylor all star move hi',
#  '551': 'chuck taylor all star move platform seasonal',
#  '552': 'chuck taylor all star ox',
#  '553': 'chuck taylor all star utility',
#  '554': 'chuck taylor alt star canvas',
#  '555': 'chukka 79 mte 1 lx',
#  '556': 'circle vee se',
#  '557': 'city classic boots',
#  '558': 'cl leather',
#  '559': 'cl leather hexalite',
#  '560': 'cl legacy az',
#  '561': 'cl legacy az grow unisex',
#  '562': 'cl nylon',
#  '563': 'clabetaic clog x western hydrodynamic research',
#  '564': 'clabetaic learher hexalite',
#  '565': 'clabetaic leather',
#  '566': 'clabetaic leather legacy az',
#  '567': 'clabetaic leather make it yours',
#  '568': 'clabetaic leather sp extra',
#  '569': 'clabetaic nylon',
#  '570': 'clabetaic nylon plus',
#  '571': 'classic hiker clog',
#  '572': 'classic hiker xscape clog',
#  '573': 'classic leather',
#  '574': 'classic leather 1983 vintage',
#  '575': 'classic leather infants',
#  '576': 'classic leather pump',
#  '577': 'classic leather shoes',
#  '578': 'classic leather sp',
#  '579': 'classic leather sp extra',
#  '580': 'classic leather vegan',
#  '581': 'classic leather vintage 40th',
#  '582': 'classic legacy',
#  '583': 'classic legacy az',
#  '584': 'classic legacy az grow',
#  '585': 'classic legacy az the jetsons meet the flintstones',
#  '586': 'classic low 2',
#  '587': 'classic mega crush clog',
#  '588': 'classic mega crush sandal',
#  '589': 'classic ro clog',
#  '590': 'classic slip on 9 anaheim factory',
#  '591': 'classic slip on 98 dx',
#  '592': 'classic slip on 98 dx anaheim factory',
#  '593': 'classic slip on lx',
#  '594': 'classic slip on lx dobale',
#  '595': 'classic slip on platform',
#  '596': 'classic slip on vr3 lx',
#  '597': 'classic sp vegan',
#  '598': 'classic sp womens vegan',
#  '599': 'clc low m',
#  '600': 'clc low w',
#  '601': 'clot chuck 70',
#  '602': 'clot jack purcell',
#  '603': 'cloudway',
#  '604': 'club c',
#  '605': 'club c 85',
#  '606': 'club c 85 fvs ps desert',
#  '607': 'club c 85 mid ii',
#  '608': 'club c 85 pump',
#  '609': 'club c 85 vintage',
#  '610': 'club c 85 vintage chalck',
#  '611': 'club c 85 x prince',
#  '612': 'club c bulc',
#  '613': 'club c cardi',
#  '614': 'club c clean',
#  '615': 'club c double geo',
#  '616': 'club c extra',
#  '617': 'club c form hi',
#  '618': 'club c geo mid',
#  '619': 'club c grounds',
#  '620': 'club c legacy jurassic park',
#  '621': 'club c mid ii revenge vintage',
#  '622': 'club c revenge',
#  '623': 'club c revenge vintage',
#  '624': 'club c vibram',
#  '625': 'clyde',
#  '626': 'clyde base',
#  '627': 'clyde culture',
#  '628': 'clyde fg',
#  '629': 'clyde og',
#  '630': 'clyde prm',
#  '631': 'clyde service line',
#  '632': 'clyde super puma',
#  '633': 'clyde vtg',
#  '634': 'coast cc circuit',
#  '635': 'coil r1 archive',
#  '636': 'coil r1 og',
#  '637': 'coil r1 og pop',
#  '638': 'coil r2',
#  '639': 'coil r3',
#  '640': 'coil rx',
#  '641': 'coil rx gorp',
#  '642': 'coldhearted comfycush authentic',
#  '643': 'comme des garcons homme plus x nike air sunder max sp',
#  '644': 'comme des garsons shirt tarther sc',
#  '645': 'condor 2 alveomesh',
#  '646': 'conductor hi',
#  '647': 'cons as 1 pro',
#  '648': 'cons chuck taylor all star pro cut off',
#  '649': 'cons louie lopez pro suede and leather',
#  '650': 'cons one star pro',
#  '651': 'cons one star pro craft south of houston',
#  '652': 'cons one star pro suede',
#  '653': 'contender',
#  '654': 'contender naruto',
#  '655': 'contender u',
#  '656': 'contenderu',
#  '657': 'continental 80',
#  '658': 'continental 80 prime',
#  '659': 'continental 80 recon',
#  '660': 'continental 80 vegan',
#  '661': 'copa nationale',
#  '662': 'cortez',
#  '663': 'cortez se',
#  '664': 'cosmic unity 2',
#  '665': 'cosmic unity 3',
#  '666': 'country human made',
#  '667': 'country og',
#  '668': 'country xlg',
#  '669': 'court borough mid 2',
#  '670': 'court legacy lift',
#  '671': 'court peak',
#  '672': 'court rider chaos team',
#  '673': 'court tourino w',
#  '674': 'court vision alta',
#  '675': 'courtic',
#  '676': 'courtside tennis mid jd2',
#  '677': 'cozy superstar',
#  '678': 'cozy zx 8000',
#  '679': 'cph eco slip on',
#  '680': 'craig green rivalry polta akh',
#  '681': 'craig green scuba s',
#  '682': 'crazy 1 basketball',
#  '683': 'crazy 8',
#  '684': 'crazy iiinfinity',
#  '685': 'crazy iiinfinity 003',
#  '686': 'cruise rider nu pastel wns',
#  '687': 'cruse rider lace mono wns',
#  '688': 'ct302',
#  '689': 'cut slices forum hi',
#  '690': 'cycloid 4',
#  '691': 'cylon',
#  '692': 'daxton',
#  '693': 'daybreak',
#  '694': 'daytona dmx ii',
#  '695': 'dc x club c joker',
#  '696': 'dekkan',
#  '697': 'dekkan alveo',
#  '698': 'dekkan alveomesh',
#  '699': 'dekkan w',
#  '700': 'dellow s strike',
#  '701': 'depa cab',
#  '702': 'descendant campus',
#  '703': 'desert boot',
#  '704': 'dime workout plus',
#  '705': 'disc blaze og',
#  '706': 'disc blaze snake',
#  '707': 'disc blaze the neverworn ii',
#  '708': 'disney stan smith',
#  '709': 'disney stan smith w',
#  '710': 'disruptor 2 animal print',
#  '711': 'diversity',
#  '712': 'don ibetaue 4',
#  '713': 'drkshdw turbodrk',
#  '714': 'dua lipa mayze sd',
#  '715': 'dunk hi 1985 sp',
#  '716': 'dunk hi retro',
#  '717': 'dunk hi retro se',
#  '718': 'dunk hi retro university',
#  '719': 'dunk high',
#  '720': 'dunk high 1985 sp',
#  '721': 'dunk high 85',
#  '722': 'dunk high retro',
#  '723': 'dunk high retro premium',
#  '724': 'dunk high retro se',
#  '725': 'dunk low',
#  '726': 'dunk low high retro se',
#  '727': 'dunk low premium',
#  '728': 'dunk low retro',
#  '729': 'dunk low retro bttys',
#  '730': 'dunk low retro mens shoes',
#  '731': 'dunk low retro premium',
#  '732': 'dylan clog',
#  '733': 'dynaflow',
#  '734': 'dynaflow vibram',
#  '735': 'e series ad',
#  '736': 'e star pro',
#  '737': 'e star pro classic suede',
#  '738': 'e star pro vintage suede',
#  '739': 'eames clabetaic leather',
#  '740': 'eames classic leather',
#  '741': 'eames classic lthr',
#  '742': 'eames classic lthr seaside',
#  '743': 'eames club c 85 shoes',
#  '744': 'echo clog',
#  '745': 'echo marbled clog',
#  '746': 'echo slide',
#  '747': 'el s strike',
#  '748': 'elite rgs',
#  '749': 'engineered garments lx 2200',
#  '750': 'epaak sport dx',
#  '751': 'equipment proto',
#  '752': 'era lx dobale',
#  '753': 'error',
#  '754': 'error arizona tech',
#  '755': 'es22',
#  '756': 'escape thrive endure',
#  '757': 'ex0tex nitro',
#  '758': 'ex89',
#  '759': 'ex89 by charlotte cardin',
#  '760': 'ex89 mt',
#  '761': 'ex89 x fujitaka',
#  '762': 'exo ii og',
#  '763': 'exomniac cushion no sleep rave club',
#  '764': 'expedition down booties',
#  '765': 'extent nitro adv',
#  '766': 'extent nitro ek balam',
#  '767': 'extent nitro heritage vapor',
#  '768': 'extent nitro mono',
#  '769': 'facet 60 outdry',
#  '770': 'facet 75 alpha outdry',
#  '771': 'facet 75 mid outdry',
#  '772': 'fairlane suede',
#  '773': 'falcon allluxe w',
#  '774': 'falcon rx w',
#  '775': 'falcon w',
#  '776': 'fenty avanti l',
#  '777': 'fenty x puma avanti',
#  '778': 'fenty x puma avanti l',
#  '779': 'fitz roy',
#  '780': 'fitz roy fs trek shell',
#  '781': 'fjord eco canvas',
#  '782': 'flap og',
#  '783': 'floatride energy 5',
#  '784': 'floatride energy 5 adventure',
#  '785': 'floatride energy x',
#  '786': 'flow futr x 2',
#  '787': 'flow morrison outdry',
#  '788': 'flow velociti wind 2',
#  '789': 'fluffipuff',
#  '790': 'fn3 s gel kayano 28',
#  '791': 'footpatrol fusion 20',
#  '792': 'forever xt wn s',
#  '793': 'forum 84 camp low',
#  '794': 'forum 84 hi',
#  '795': 'forum 84 hi w',
#  '796': 'forum 84 high',
#  '797': 'forum 84 low',
#  '798': 'forum 84 low 8k',
#  '799': 'forum 84 low cl',
#  '800': 'forum 84 low w',
#  '801': 'forum bold stripes w',
#  '802': 'forum bold w',
#  '803': 'forum bonega w',
#  '804': 'forum boot',
#  '805': 'forum low',
#  '806': 'forum low c w',
#  '807': 'forum low cl',
#  '808': 'forum low cl w',
#  '809': 'forum low human made',
#  '810': 'forum low w',
#  '811': 'forum low x andre saraiva',
#  '812': 'forum mid',
#  '813': 'forum mid parley',
#  '814': 'forum mid w',
#  '815': 'forum millencon w',
#  '816': 'forum mod low',
#  '817': 'forum mod mid',
#  '818': 'forum platform',
#  '819': 'forum xlg w',
#  '820': 'fragment weapon',
#  '821': 'freak 5 ep',
#  '822': 'free og sp',
#  '823': 'free run trail',
#  '824': 'free run trail crater',
#  '825': 'free terra vista',
#  '826': 'full force low',
#  '827': 'fusion 20',
#  '828': 'fusion xc',
#  '829': 'fusion xc mount saana',
#  '830': 'future rider cut out wns',
#  '831': 'future rider override',
#  '832': 'future runner og',
#  '833': 'futurepacer',
#  '834': 'game lo',
#  '835': 'gamma force w',
#  '836': 'garfield suede',
#  '837': 'gazelle',
#  '838': 'gazelle 85',
#  '839': 'gazelle bold',
#  '840': 'gazelle bold w',
#  '841': 'gazelle boot w',
#  '842': 'gazelle indoor',
#  '843': 'gazelle indoor w',
#  '844': 'gazelle w',
#  '845': 'gel 1090',
#  '846': 'gel 1090 v2',
#  '847': 'gel 1090v2',
#  '848': 'gel 1130',
#  '849': 'gel 1130 w',
#  '850': 'gel kayano 14',
#  '851': 'gel kayano 21',
#  '852': 'gel kayano 29 lite show',
#  '853': 'gel kayano 51',
#  '854': 'gel kayano legacy',
#  '855': 'gel lyte iii',
#  '856': 'gel lyte iii og',
#  '857': 'gel lyte iii og ash rock',
#  '858': 'gel lyte iii og recycle felt oyster gray diva',
#  '859': 'gel lyte v',
#  '860': 'gel lyte v godai',
#  '861': 'gel lyte v spring in japan',
#  '862': 'gel nimbus 9',
#  '863': 'gel nyc',
#  '864': 'gel quantum 180',
#  '865': 'gel quantum 180 vii',
#  '866': 'gel quantum 360 vii',
#  '867': 'gel quantum kinetic',
#  '868': 'gel sonoma 15 50',
#  '869': 'gel trabuco 11 gtx',
#  '870': 'gel trabuco terra sps',
#  '871': 'gel venture 6',
#  '872': 'gel venture 6 ns',
#  '873': 'gelsaga sou',
#  '874': 'gendo superstar',
#  '875': 'general purpose',
#  '876': 'geo forma',
#  '877': 'ghica popa',
#  '878': 'ghica popa spaceship',
#  '879': 'giannis antetokounmpo freak 5 ep',
#  '880': 'gmbh gel kayano legacy',
#  '881': 'golf wang chuck 70 ox',
#  '882': 'golf wang chuck 70 ox owl camo',
#  '883': 'goodfight og style 93 lx',
#  '884': 'gr1p',
#  '885': 'gr1p high',
#  '886': 'grandstand ii',
#  '887': 'grid shadow 2',
#  '888': 'grid shadow 2 og',
#  '889': 'groundhog day supernova cushion 7',
#  '890': 'gryphon',
#  '891': 'gryphon alt 2 strap sandal',
#  '892': 'gsg9',
#  '893': 'gt 2160',
#  '894': 'gt 2160 kogarashi',
#  '895': 'guam',
#  '896': 'gv 87',
#  '897': 'half cab 33',
#  '898': 'half cab 33 dx',
#  '899': 'half cab 33 dx anaheim factory',
#  '900': 'half cab cp vr3 lx',
#  '901': 'half cab ef lx',
#  '902': 'half cab gore tex mte 3',
#  '903': 'half cab hiker',
#  '904': 'half cab lx',
#  '905': 'hand 2',
#  '906': 'handball spezial',
#  '907': 'harden volume 7 chp',
#  '908': 'hartness spzl',
#  '909': 'hedra fantasy wns',
#  '910': 'hello kitty air presto',
#  '911': 'hello kitty air presto toddler',
#  '912': 'hello kitty air presto younger kids',
#  '913': 'hello kitty forum low w',
#  '914': 'her court w',
#  '915': 'hexalite legacy',
#  '916': 'hexalite legacy 15',
#  '917': 'hicho',
#  '918': 'hokori iii',
#  '919': 'hokori sandal',
#  '920': 'homer simpson stan smith',
#  '921': 'hood river slide',
#  '922': 'hovr apex 3',
#  '923': 'hovr flux',
#  '924': 'hovr flux mvmnt',
#  '925': 'hovr infinite 3',
#  '926': 'hovr machina 3',
#  '927': 'hovr machina breeze',
#  '928': 'hovr machina off road',
#  '929': 'hovr mega 2',
#  '930': 'hovr mega 3 clone',
#  '931': 'hovr phantom 2 inknt blk',
#  '932': 'hovr phantom 3',
#  '933': 'hovr sonic 5',
#  '934': 'hts rgs',
#  '935': 'hts shadow',
#  '936': 'hts shadow black coffee',
#  '937': 'hts shadow dark forest',
#  '938': 'hts shadow rgs',
#  '939': 'hu nmd animal print',
#  '940': 'hu nmd s1 ryat',
#  '941': 'huarache craft',
#  '942': 'huarache gs',
#  '943': 'huarache run gs',
#  '944': 'huarache runner',
#  '945': 'humanrace samba',
#  '946': 'humanrace sichona',
#  '947': 'hurrikaze ii',
#  '948': 'hydro xi',
#  '949': 'hyperturf',
#  '950': 'hyperturf adventure',
#  '951': 'hyperturf w',
#  '952': 'ibn jasper one star',
#  '953': 'ic0 slide',
#  '954': 'ico aratana sneaker',
#  '955': 'icon low nylon',
#  '956': 'icon nylon',
#  '957': 'icon pumps bi',
#  '958': 'icon satin glance',
#  '959': 'idoso boost',
#  '960': 'ikoni trail',
#  '961': 'ikoni trail wr',
#  '962': 'instapump fury 95',
#  '963': 'instapump fury boost',
#  '964': 'instapump fury og',
#  '965': 'internationalist',
#  '966': 'iverson basketball shorts',
#  '967': 'ivy park forum mid',
#  '968': 'ja 1 ep',
#  '969': 'ja 1 nrg ep',
#  '970': 'ja morant ja 1 ep',
#  '971': 'jadon',
#  '972': 'jadon 8 eye boot',
#  '973': 'jadon fl 8 eye boot',
#  '974': 'jadon hdw ii',
#  '975': 'jadon leather',
#  '976': 'jadon polished smooth',
#  '977': 'japan s',
#  '978': 'japan s pf',
#  '979': 'japan s st',
#  '980': 'japan s stack',
#  '981': 'jayson tatum 1 pf',
#  '982': 'jeremy scott opal wings 40',
#  '983': 'jogger x81',
#  '984': 'john elliott skidgrip',
#  '985': 'josh boot',
#  '986': 'joshua vides cx weapon',
#  '987': 'joshua vides pro leather',
#  '988': 'joyride cc3 setter mmw',
#  '989': 'julian klincewicz og authentic sp lx hairy suede',
#  '990': 'june batwing',
#  '991': 'june batwing s',
#  '992': 'june poster s',
#  '993': 'jurassic stomper',
#  '994': 'jute wrap boat',
#  '995': 'kaiwa',
#  '996': 'kd15 ep',
#  '997': 'kd16 ep',
#  '998': 'kd16 nrg ep',
#  '999': 'keith haring pro leather ox',
#  ...}

# %%
similar_models = np.vectorize(temp.idx_to_class.get)(similar_objects[:, 1])

